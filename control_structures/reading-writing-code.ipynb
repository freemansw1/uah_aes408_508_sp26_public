# %% [markdown]
# # Reading and Writing Code

# %%
numbers = [1, 2, 3, 4, 5]
total = 0
for num in numbers:
    if num % 3 == 0:
        total += num
    else:
        total += num * 2
print(f"Result: {total}")
# Out:
# Result: 27

# %% [markdown]
# Before we go and run that, let's explore the stuff we don't know.

# %% [markdown]
# ## Modulus (%)

# %%
4%2
# Out:
# 0

# %%
3%2
# Out:
# 1

# %%
10001%2
# Out:
# 1

# %%
40%10
# Out:
# 0

# %% [markdown]
# ## Plus-Equals (+=)

# %%
x = 0
x+=2
x+=3
x
# Out:
# 5

# %%
x+=49

# %%
x
# Out:
# 54

# %%
x-=49
x
# Out:
# 5

# %% [markdown]
# ## Formatting Strings

# %%
print(f"hello: {x}")
# Out:
# hello: 5

# %%
print(f"hello: {x:5.4f}")
# Out:
# hello: 5.0000
