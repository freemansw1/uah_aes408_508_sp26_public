# %% [markdown]
# https://pandas.pydata.org/docs/index.html

# %%
import pandas as pd
import numpy as np

# %%
in_gauges = pd.read_csv("../example_data/nwps_all_gauges_report.csv")

# %%
in_gauges
# Out:
#                                               location name  proximity  \
# Cheyenne River above Angostura at Hwy 71                NaN        NaN
# Williamson Creek at Manchaca Road at Austin             NaN        NaN
# Antler River below Antler Lake near Auke Bay            NaN        NaN
# San Francisco Bay  Alameda tide gage                    NaN        NaN
# Peachtree Creek at Atlanta                              NaN        NaN
# ...                                                     ...        ...
# Zekiah Swamp Run near Newtown                           NaN        NaN
# Pennsylvania Run near Zoneton                           NaN        NaN
# Zuni River above Black Rock Reservoir                   NaN        NaN
# Zumbro River at Zumbro Falls                            NaN        NaN
# Blackwater River (VA) near ZUNI                         NaN        NaN
#
#                                              river/water-body name  \
# Cheyenne River above Angostura at Hwy 71                     AACS2
# Williamson Creek at Manchaca Road at Austin                  AAIT2
# Antler River below Antler Lake near Auke Bay                 AAKA2
# San Francisco Bay  Alameda tide gage                         AAMC1
# Peachtree Creek at Atlanta                                   AANG1
# ...                                                            ...
# Zekiah Swamp Run near Newtown                                ZSRM2
# Pennsylvania Run near Zoneton                                ZTNK2
# Zuni River above Black Rock Reservoir                        ZUIN5
# Zumbro River at Zumbro Falls                                 ZUMM5
# Blackwater River (VA) near ZUNI                              ZUNV2
#
#                                               nws shef id location type  \
# Cheyenne River above Angostura at Hwy 71              NaN           NaN
# Williamson Creek at Manchaca Road at Austin           NaN      08158930
# Antler River below Antler Lake near Auke Bay          NaN      15055500
# San Francisco Bay  Alameda tide gage                  NaN           NaN
# Peachtree Creek at Atlanta                            NaN      02336300
# ...                                                   ...           ...
# Zekiah Swamp Run near Newtown                         NaN      01660920
# Pennsylvania Run near Zoneton                         NaN      03298300
# Zuni River above Black Rock Reservoir                 NaN      09386950
# Zumbro River at Zumbro Falls                          NaN      05374000
# Blackwater River (VA) near ZUNI                       NaN      02047783
#
#                                                 usgs id    latitude longitude  \
# Cheyenne River above Angostura at Hwy 71      43.305770 -103.562797       UNR
# Williamson Creek at Manchaca Road at Austin   30.221111  -97.793333       EWX
# Antler River below Antler Lake near Auke Bay  58.851944 -134.708611       AJK
# San Francisco Bay  Alameda tide gage          37.771667 -122.298333       MTR
# Peachtree Creek at Atlanta                    33.820306  -84.407639       FFC
# ...                                                 ...         ...       ...
# Zekiah Swamp Run near Newtown                 38.490556  -76.927222       LWX
# Pennsylvania Run near Zoneton                 38.087566  -85.642458       LMK
# Zuni River above Black Rock Reservoir         35.100278 -108.751667       ABQ
# Zumbro River at Zumbro Falls                  44.285600  -92.430000       ARX
# Blackwater River (VA) near ZUNI               36.906389  -76.820278       AKQ
#
#                                                 wfo rfc  ...  \
# Cheyenne River above Angostura at Hwy 71      MBRFC  SD  ...
# Williamson Creek at Manchaca Road at Austin   WGRFC  TX  ...
# Antler River below Antler Lake near Auke Bay  APRFC  AK  ...
# San Francisco Bay  Alameda tide gage          CNRFC  CA  ...
# Peachtree Creek at Atlanta                    SERFC  GA  ...
# ...                                             ...  ..  ...
# Zekiah Swamp Run near Newtown                 MARFC  MD  ...
# Pennsylvania Run near Zoneton                 OHRFC  KY  ...
# Zuni River above Black Rock Reservoir         CBRFC  NM  ...
# Zumbro River at Zumbro Falls                  NCRFC  MN  ...
# Blackwater River (VA) near ZUNI               SERFC  VA  ...
#
#                                              probabilistic site  \
# Cheyenne River above Angostura at Hwy 71                  False
# Williamson Creek at Manchaca Road at Austin               False
# Antler River below Antler Lake near Auke Bay              False
# San Francisco Bay  Alameda tide gage                      False
# Peachtree Creek at Atlanta                                 True
# ...                                                         ...
# Zekiah Swamp Run near Newtown                             False
# Pennsylvania Run near Zoneton                             False
# Zuni River above Black Rock Reservoir                     False
# Zumbro River at Zumbro Falls                               True
# Blackwater River (VA) near ZUNI                           False
#
#                                               weekly chance probabilistic enabled  \
# Cheyenne River above Angostura at Hwy 71                                    False
# Williamson Creek at Manchaca Road at Austin                                 False
# Antler River below Antler Lake near Auke Bay                                False
# San Francisco Bay  Alameda tide gage                                        False
# Peachtree Creek at Atlanta                                                   True
# ...                                                                           ...
# Zekiah Swamp Run near Newtown                                               False
# Pennsylvania Run near Zoneton                                               False
# Zuni River above Black Rock Reservoir                                        True
# Zumbro River at Zumbro Falls                                                 True
# Blackwater River (VA) near ZUNI                                             False
#
#                                              short-term probabilistic enabled  \
# Cheyenne River above Angostura at Hwy 71                                False
# Williamson Creek at Manchaca Road at Austin                             False
# Antler River below Antler Lake near Auke Bay                            False
# San Francisco Bay  Alameda tide gage                                    False
# Peachtree Creek at Atlanta                                               True
# ...                                                                       ...
# Zekiah Swamp Run near Newtown                                           False
# Pennsylvania Run near Zoneton                                           False
# Zuni River above Black Rock Reservoir                                   False
# Zumbro River at Zumbro Falls                                             True
# Blackwater River (VA) near ZUNI                                         False
#
#                                               chance of exceeding probabilistic enabled  \
# Cheyenne River above Angostura at Hwy 71                                         NAVD88
# Williamson Creek at Manchaca Road at Austin                                         NaN
# Antler River below Antler Lake near Auke Bay                                       STND
# San Francisco Bay  Alameda tide gage                                                NaN
# Peachtree Creek at Atlanta                                                       NAVD88
# ...                                                                                 ...
# Zekiah Swamp Run near Newtown                                                    NAVD88
# Pennsylvania Run near Zoneton                                                    NAVD88
# Zuni River above Black Rock Reservoir                                            NGVD29
# Zumbro River at Zumbro Falls                                                     NAVD88
# Blackwater River (VA) near ZUNI                                                  NAVD88
#
#                                               nrldb vertical datum name  \
# Cheyenne River above Angostura at Hwy 71                           0.00
# Williamson Creek at Manchaca Road at Austin                         NaN
# Antler River below Antler Lake near Auke Bay                       0.00
# San Francisco Bay  Alameda tide gage                                NaN
# Peachtree Creek at Atlanta                                       764.13
# ...                                                                 ...
# Zekiah Swamp Run near Newtown                                     34.05
# Pennsylvania Run near Zoneton                                    522.70
# Zuni River above Black Rock Reservoir                           6450.00
# Zumbro River at Zumbro Falls                                     811.35
# Blackwater River (VA) near ZUNI                                    0.00
#
#                                               nrldb vertical datum  \
# Cheyenne River above Angostura at Hwy 71                       NaN
# Williamson Creek at Manchaca Road at Austin                    NaN
# Antler River below Antler Lake near Auke Bay                   NaN
# San Francisco Bay  Alameda tide gage                           NaN
# Peachtree Creek at Atlanta                                     NaN
# ...                                                            ...
# Zekiah Swamp Run near Newtown                                  NaN
# Pennsylvania Run near Zoneton                                  NaN
# Zuni River above Black Rock Reservoir                          NaN
# Zumbro River at Zumbro Falls                                   NaN
# Blackwater River (VA) near ZUNI                                NaN
#
#                                               navd88 vertical datum  \
# Cheyenne River above Angostura at Hwy 71                        NaN
# Williamson Creek at Manchaca Road at Austin                     NaN
# Antler River below Antler Lake near Auke Bay                    NaN
# San Francisco Bay  Alameda tide gage                            NaN
# Peachtree Creek at Atlanta                                      NaN
# ...                                                             ...
# Zekiah Swamp Run near Newtown                                   NaN
# Pennsylvania Run near Zoneton                                   NaN
# Zuni River above Black Rock Reservoir                           NaN
# Zumbro River at Zumbro Falls                                    NaN
# Blackwater River (VA) near ZUNI                                 NaN
#
#                                               ngvd29 vertical datum  \
# Cheyenne River above Angostura at Hwy 71                        NaN
# Williamson Creek at Manchaca Road at Austin                     NaN
# Antler River below Antler Lake near Auke Bay                    NaN
# San Francisco Bay  Alameda tide gage                            NaN
# Peachtree Creek at Atlanta                                      NaN
# ...                                                             ...
# Zekiah Swamp Run near Newtown                                   NaN
# Pennsylvania Run near Zoneton                                   NaN
# Zuni River above Black Rock Reservoir                           NaN
# Zumbro River at Zumbro Falls                                    NaN
# Blackwater River (VA) near ZUNI                                 NaN
#
#                                               msl vertical datum  \
# Cheyenne River above Angostura at Hwy 71                     NaN
# Williamson Creek at Manchaca Road at Austin                  NaN
# Antler River below Antler Lake near Auke Bay                 NaN
# San Francisco Bay  Alameda tide gage                         NaN
# Peachtree Creek at Atlanta                                   NaN
# ...                                                          ...
# Zekiah Swamp Run near Newtown                                NaN
# Pennsylvania Run near Zoneton                                NaN
# Zuni River above Black Rock Reservoir                        NaN
# Zumbro River at Zumbro Falls                                 NaN
# Blackwater River (VA) near ZUNI                              NaN
#
#                                              other vertical datum
# Cheyenne River above Angostura at Hwy 71                      NaN
# Williamson Creek at Manchaca Road at Austin                   NaN
# Antler River below Antler Lake near Auke Bay                  NaN
# San Francisco Bay  Alameda tide gage                          NaN
# Peachtree Creek at Atlanta                                    NaN
# ...                                                           ...
# Zekiah Swamp Run near Newtown                                 NaN
# Pennsylvania Run near Zoneton                                 NaN
# Zuni River above Black Rock Reservoir                         NaN
# Zumbro River at Zumbro Falls                                  NaN
# Blackwater River (VA) near ZUNI                               NaN
#
# [12105 rows x 43 columns]

# %%
in_gauges.columns

# %%
in_gauges.head()

# %%
in_gauges['wfo'].unique()

# %%
in_gauges['state'].unique()

# %% [markdown]
# That doesn't seem right...

# %%
in_gauges = pd.read_csv("../example_data/nwps_all_gauges_report.csv", index_col=False)

# %%
in_gauges['state'].unique()
# Out:
# <StringArray>
# ['SD', 'TX', 'AK', 'CA', 'GA', 'IN', 'NC', 'VA', 'MS', 'MD', 'KS', 'NM', 'LA',
#  'MT', 'KY', 'NE', 'ND', 'WV', 'NJ', 'ME', 'WA', 'PA', 'OK', 'SC', 'TN', 'ID',
#  'FL', 'OH', 'OR', 'CO', 'MI', 'IA', 'NY', 'MN', 'IL', 'AZ', 'UT', 'WI', 'AL',
#  'MO', 'PR', 'AR', 'WY', 'HI', 'NH', 'DC', 'MA', 'VT', 'CT', 'DE', 'NV', 'RI']
# Length: 52, dtype: str

# %%
in_gauges

# %%
in_gauges['major flood stage']

# %%
in_gauges.loc[in_gauges['major flood stage']==-9999, "major flood stage"] = np.nan

# %%
in_gauges['major flood stage'].hist()
# Out:
# <Axes: >
