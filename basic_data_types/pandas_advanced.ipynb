# %% [markdown]
# https://pandas.pydata.org/docs/index.html

# %%
import pandas as pd
import numpy as np

# %%
squirel_dataset = pd.read_csv(r"..\example_data\2018_Central_Park_Squirrel_Census_-_Squirrel_Data_20260205.csv",
                              parse_dates=['Date'], date_format="%m%d%Y")

# %%
squirel_dataset['Date']
# Out:
# 0      2018-10-14
# 1      2018-10-19
# 2      2018-10-14
# 3      2018-10-17
# 4      2018-10-17
#           ...
# 3018   2018-10-07
# 3019   2018-10-13
# 3020   2018-10-12
# 3021   2018-10-10
# 3022   2018-10-12
# Name: Date, Length: 3023, dtype: datetime64[us]

# %%
squirel_dataset
# Out:
#               X          Y Unique Squirrel ID Hectare Shift       Date  \
# 0    -73.956134  40.794082     37F-PM-1014-03     37F    PM 2018-10-14
# 1    -73.968857  40.783783     21B-AM-1019-04     21B    AM 2018-10-19
# 2    -73.974281  40.775534     11B-PM-1014-08     11B    PM 2018-10-14
# 3    -73.959641  40.790313     32E-PM-1017-14     32E    PM 2018-10-17
# 4    -73.970268  40.776213     13E-AM-1017-05     13E    AM 2018-10-17
# ...         ...        ...                ...     ...   ...        ...
# 3018 -73.963943  40.790868     30B-AM-1007-04     30B    AM 2018-10-07
# 3019 -73.970402  40.782560     19A-PM-1013-05     19A    PM 2018-10-13
# 3020 -73.966587  40.783678     22D-PM-1012-07     22D    PM 2018-10-12
# 3021 -73.963994  40.789915     29B-PM-1010-02     29B    PM 2018-10-10
# 3022 -73.975479  40.769640      5E-PM-1012-01     05E    PM 2018-10-12
#
#       Hectare Squirrel Number    Age Primary Fur Color  \
# 0                           3    NaN               NaN
# ...

# %%
squirel_dataset.groupby("Date").count()['X']
# Out:
# Date
# 2018-10-06    337
# 2018-10-07    405
# 2018-10-08    285
# 2018-10-10    335
# 2018-10-12    218
# 2018-10-13    434
# 2018-10-14    368
# 2018-10-17    216
# 2018-10-18    200
# 2018-10-19    158
# 2018-10-20     67
# Name: X, dtype: int64

# %%
squirel_dataset.groupby("Shift").count()['X']
# Out:
# Shift
# AM    1347
# PM    1676
# Name: X, dtype: int64
