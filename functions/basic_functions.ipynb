# %% [markdown]
# # Basic Python Functions

# %%
def func(x):
    return x * 2
print(func(5))
# Out:
# 10

# %%
def hello():
    print("hello!")
hello()
# Out:
# hello!

# %%
def test1():
    return 4

# %%
from datetime import datetime as dt
import datetime
def what_time():
    return dt.now(datetime.UTC)

# %%
what_time()
# Out:
# datetime.datetime(2026, 2, 17, 16, 27, 5, 390864, tzinfo=datetime.timezone.utc)

# %%
def test2():
    return 4,9

# %%
def test2():
    for i in range(10):
        if i == 5:
            return
        print(i)

# %%
test2()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
def add(a, b):
    return a + b
add(3,4)
# Out:
# 7

# %%
def add_with_times(a, b):
    return a + b*2
add_with_times(3,4), add_with_times(4,3)
# Out:
# (11, 10)

# %%
def add_with_times(a=0, b=0):
    return a + b*2
add_with_times(3,4), add_with_times(4,3)
# Out:
# (11, 10)

# %%
def add_with_times(a=0, b=0):
    return a + b*2
add_with_times(3,4), add_with_times(4,3)
# Out:
# (11, 10)

# %%
def add(*args):
    total=0
    for arg in args:
        total+=arg
    return total

# both valid
print(add(1,2,3))
print(add(3,4,5,6,7,2,1,2,3,4))
# Out:
# 6
# 37

# %%
# from the python documentation

def cheeseshop(kind, *arguments, **keywords):
    print("-- Do you have any", kind, "?")
    print("-- I'm sorry, we're all out of", kind)
    for arg in arguments:
        print(arg)
    print("-" * 40)
    for kw in keywords:
        print(kw, ":", keywords[kw])

# %%
cheeseshop("Limburger", "It's very runny, sir.",
           "It's really very, VERY runny, sir.",
           shopkeeper="Michael Palin",
           client="John Cleese",
           sketch="Cheese Shop Sketch")
# Out:
# -- Do you have any Limburger ?
# -- I'm sorry, we're all out of Limburger
# It's very runny, sir.
# It's really very, VERY runny, sir.
# ----------------------------------------
# shopkeeper : Michael Palin
# client : John Cleese
# sketch : Cheese Shop Sketch

# %%
# from the Python documentation
def standard_arg(arg):
    print(arg)

def pos_only_arg(arg, /):
    print(arg)

def kwd_only_arg(*, arg):
    print(arg)

def combined_example(pos_only, /, standard, *, kwd_only):
    print(pos_only, standard, kwd_only)

# %%
def long_arg_function(a=4, b=7, c=9, d=3, e=2, f=1):
    print(a, b, c, d, e, f)

test_params = dict()
test_params['a'] = 40
test_params['b'] = 70
test_params['c'] = 90

test_params['d'] = 30
test_params['e'] = 20
test_params['f'] = 10
long_arg_function(**test_params)
# Out:
# 40 70 90 30 20 10

# %%
def test_func(x):
    print(x)

# %%
test_func("hello!")
# Out:
# hello!

# %%
import geopandas as gpd

# %%
def open_shapefile_al(x):
    full_fil = gpd.read_file(x)
    return full_fil[full_fil['STUSPS'] == 'AL']

# %%
open_shapefile_al(r"..\example_data\cb_2018_us_state_20m\cb_2018_us_state_20m.shp")
# Out:
#   STATEFP  ...                                           geometry
# 8      01  ...  POLYGON ((-88.46866 31.89386, -88.46866 31.933...
#
# [1 rows x 10 columns]
