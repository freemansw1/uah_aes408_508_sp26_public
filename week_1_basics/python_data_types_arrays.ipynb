# %% [markdown]
# # Basic Python Arrays

# %% [markdown]
# ## Lists

# %%
x = [1, 2, 3]

# %%
x
# Out:
# [1, 2, 3]

# %%
x[1] = 45
x
# Out:
# [1, 45, 3]

# %%
for item in x:
    print(item)
# Out:
# 1
# 45
# 3

# %%
for item in sorted(x):
    print(item)
x
# Out:
# 1
# 3
# 45
# [1, 45, 3]

# %% [markdown]
# ## Tuples

# %%
y = (1, 2, 3)
y
# Out:
# (1, 2, 3)

# %%
y[2]
# Out:
# 3

# %%
y[1] = 45
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 y[1] = 45
#
# TypeError: 'tuple' object does not support item assignment

# %%
for item in x:
    print(item)
# Out:
# 1
# 45
# 3

# %%
x = [(30, -85), (31, -86), (32, -87)]
for item in x:
    print(item)
# Out:
# (30, -85)
# (31, -86)
# (32, -87)

# %% [markdown]
# ## Sets

# %%
x = {1,2,3}

# %%
x
# Out:
# {1, 2, 3}

# %%
x[2] = 30
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 x[2] = 30
#
# TypeError: 'set' object does not support item assignment

# %%
x = {1, 2, 3, 3, 4}

# %%
x
# Out:
# {1, 2, 3, 4}

# %%
for item in x: 
    print(item)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# Unlike lists and tuples, sets don't keep item order intact.

# %%
x = {1, 2, 51, 3, 4}

# %%
x
# Out:
# {1, 2, 3, 4, 51}

# %% [markdown]
# ## Dictionaries

# %%
x = {"hello": 23, "world": 45}
x
# Out:
# {'hello': 23, 'world': 45}

# %%
for item in x: 
    print(item)
# Out:
# hello
# world

# %%
for item in x: 
    print(x[item])
# Out:
# 23
# 45
