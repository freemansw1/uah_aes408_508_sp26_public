# %%
import geopandas as gpd
import folium

# %%
roads_shpfil = gpd.read_file("../example_data/tl_2025_01089_roads/tl_2025_01089_roads.shp")

# %%
roads_shpfil.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# ...

# %%
roads_reproj = roads_shpfil.to_crs(epsg=4326)
