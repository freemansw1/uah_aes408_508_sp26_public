# %%
import requests

# %%
output = requests.get('https://api.waterdata.usgs.gov/ogcapi/v0/collections/continuous/items/036a9795-79f7-4b8a-a87a-d02359caefa7?f=json',)

# %%
output.json()['type']
# Out:
# 'Feature'
